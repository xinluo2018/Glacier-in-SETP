# %% [markdown]
# ### **Icesat-2 data read out.**

# %%
import os
os.chdir('..')
import h5py
import cartopy.crs as ccrs
from notebooks import config
from utils.imgShow import imgShow
import matplotlib.pyplot as plt
from utils.geotif_io import readTiff
from utils.transform_xy import coor2coor
import numpy as np

# %%
### read in and write out
## atl03
# !h5ls data/icesat2/download_atl03/processed_ATL03_20200101005343_00810606_004_01.h5
# !python utils/readout03.py data/icesat2/download_atl03/data_202012/*ATL03*.h5 -o data/icesat2/processed_atl03/data_202012 -n 4
## atl06
# !h5ls data/icesat2/download_atl06/processed_ATL06_20200105004522_01420606_004_01.h5
# !python utils/readout06.py data/icesat2/download_atl06/data_202001/*ATL06*.h5 -o data/icesat2/processed_atl06/data_202001 -n 4
# Out:
# running in parallel (4 jobs) ...
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# written file: data/icesat2/processed_atl06/data_202001/processed_ATL06_20200109003702_02030606_004_01_gt1l_spot6_D.h5
# written file: data/icesat2/processed_atl06/data_202001/processed_ATL06_20200105004522_01420606_004_01_gt1l_spot6_D.h5
# written file: data/icesat2/processed_atl06/data_202001/processed_ATL06_20200110122112_02260602_004_01_gt1l_spot6_A.h5
# written file: data/icesat2/processed_atl06/data_202001/processed_ATL06_20200114121252_02870602_004_01_gt1l_spot6_A.h5
# written file: data/icesat2/processed_atl06/data_202001/processed_ATL06_20200109003702_02030606_004_01_gt1r_spot5_D.h5
# written file: data/icesat2/processed_atl06/data_202001/processed_ATL06_20200114121252_02870602_004_01_gt1r_spot5_A.h5
# written file: data/icesat2/processed_atl06/data_202001/processed_ATL06_20200105004522_01420606_004_01_gt1r_spot5_D.h5
# ...

# %%
#### atl03

## ascending
# !python utils/merge_files.py data/icesat2/processed_atl03/*ATL03*_spot1_A*.h5 -o data/icesat2/processed_atl03/atl03_spot1_A.h5
# !python utils/merge_files.py data/icesat2/processed_atl03/*ATL03*_spot2_A*.h5 -o data/icesat2/processed_atl03/atl03_spot2_A.h5
# !python utils/merge_files.py data/icesat2/processed_atl03/*ATL03*_spot3_A*.h5 -o data/icesat2/processed_atl03/atl03_spot3_A.h5
# !python utils/merge_files.py data/icesat2/processed_atl03/*ATL03*_spot4_A*.h5 -o data/icesat2/processed_atl03/atl03_spot4_A.h5
# !python utils/merge_files.py data/icesat2/processed_atl03/*ATL03*_spot5_A*.h5 -o data/icesat2/processed_atl03/atl03_spot5_A.h5
# !python utils/merge_files.py data/icesat2/processed_atl03/*ATL03*_spot6_A*.h5 -o data/icesat2/processed_atl03/atl03_spot6_A.h5

# ### descending
# !python utils/merge_files.py data/icesat2/processed_atl03/*ATL03*_spot1_D*.h5 -o data/icesat2/processed_atl03/atl03_spot1_D.h5
# !python utils/merge_files.py data/icesat2/processed_atl03/*ATL03*_spot2_D*.h5 -o data/icesat2/processed_atl03/atl03_spot2_D.h5
# !python utils/merge_files.py data/icesat2/processed_atl03/*ATL03*_spot3_D*.h5 -o data/icesat2/processed_atl03/atl03_spot3_D.h5
# !python utils/merge_files.py data/icesat2/processed_atl03/*ATL03*_spot4_D*.h5 -o data/icesat2/processed_atl03/atl03_spot4_D.h5
# !python utils/merge_files.py data/icesat2/processed_atl03/*ATL03*_spot5_D*.h5 -o data/icesat2/processed_atl03/atl03_spot5_D.h5
# !python utils/merge_files.py data/icesat2/processed_atl03/*ATL03*_spot6_D*.h5 -o data/icesat2/processed_atl03/atl03_spot6_D.h5
# Out:
# Running sequential code ...
# Calculating lenght of output from all input files ...
# ('reading', 'data/icesat2/processed_atl03/processed_ATL03_20200105004522_01420606_004_01_gt3r_spot1_D.h5')
# ('reading', 'data/icesat2/processed_atl03/processed_ATL03_20200109003702_02030606_004_01_gt3r_spot1_D.h5')
# ('reading', 'data/icesat2/processed_atl03/processed_ATL03_20200110122112_02260602_004_01_gt3r_spot1_D.h5')
# ('reading', 'data/icesat2/processed_atl03/processed_ATL03_20200105004522_01420606_004_01_gt3r_spot1_D.h5')
# ('reading', 'data/icesat2/processed_atl03/processed_ATL03_20200109003702_02030606_004_01_gt3r_spot1_D.h5')
# ('reading', 'data/icesat2/processed_atl03/processed_ATL03_20200110122112_02260602_004_01_gt3r_spot1_D.h5')
# ('reading', 'data/icesat2/processed_atl03/processed_ATL03_20200105004522_01420606_004_01_gt3r_spot1_D.h5')
# ('reading', 'data/icesat2/processed_atl03/processed_ATL03_20200109003702_02030606_004_01_gt3r_spot1_D.h5')
# ...

# %%
#### atl06
## merge data into specific spot
## ascending
# !python utils/merge_files.py data/icesat2/processed_atl06/*ATL06*_spot1_A*.h5 -o data/icesat2/processed_atl06/atl06_spot1_A.h5
# !python utils/merge_files.py data/icesat2/processed_atl06/*ATL06*_spot2_A*.h5 -o data/icesat2/processed_atl06/atl06_spot2_A.h5
# !python utils/merge_files.py data/icesat2/processed_atl06/*ATL06*_spot3_A*.h5 -o data/icesat2/processed_atl06/atl06_spot3_A.h5
# !python utils/merge_files.py data/icesat2/processed_atl06/*ATL06*_spot4_A*.h5 -o data/icesat2/processed_atl06/atl06_spot4_A.h5
# !python utils/merge_files.py data/icesat2/processed_atl06/*ATL06*_spot5_A*.h5 -o data/icesat2/processed_atl06/atl06_spot5_A.h5
# !python utils/merge_files.py data/icesat2/processed_atl06/*ATL06*_spot6_A*.h5 -o data/icesat2/processed_atl06/atl06_spot6_A.h5

# ### descending
# !python utils/merge_files.py data/icesat2/processed_atl06/*ATL06*_spot1_D*.h5 -o data/icesat2/processed_atl06/atl06_spot1_D.h5
# !python utils/merge_files.py data/icesat2/processed_atl06/*ATL06*_spot2_D*.h5 -o data/icesat2/processed_atl06/atl06_spot2_D.h5
# !python utils/merge_files.py data/icesat2/processed_atl06/*ATL06*_spot3_D*.h5 -o data/icesat2/processed_atl06/atl06_spot3_D.h5
# !python utils/merge_files.py data/icesat2/processed_atl06/*ATL06*_spot4_D*.h5 -o data/icesat2/processed_atl06/atl06_spot4_D.h5
# !python utils/merge_files.py data/icesat2/processed_atl06/*ATL06*_spot5_D*.h5 -o data/icesat2/processed_atl06/atl06_spot5_D.h5
# !python utils/merge_files.py data/icesat2/processed_atl06/*ATL06*_spot6_D*.h5 -o data/icesat2/processed_atl06/atl06_spot6_D.h5
# Out:
# Running sequential code ...
# Calculating lenght of output from all input files ...
# ('reading', 'data/icesat2/processed_atl06/processed_ATL06_20200110122112_02260602_004_01_gt3r_spot1_A.h5')
# ('reading', 'data/icesat2/processed_atl06/processed_ATL06_20200114121252_02870602_004_01_gt3r_spot1_A.h5')
# ('reading', 'data/icesat2/processed_atl06/processed_ATL06_20200118120432_03480602_004_01_gt3r_spot1_A.h5')
# ('reading', 'data/icesat2/processed_atl06/processed_ATL06_20200110122112_02260602_004_01_gt3r_spot1_A.h5')
# ('reading', 'data/icesat2/processed_atl06/processed_ATL06_20200114121252_02870602_004_01_gt3r_spot1_A.h5')
# ('reading', 'data/icesat2/processed_atl06/processed_ATL06_20200118120432_03480602_004_01_gt3r_spot1_A.h5')
# ('reading', 'data/icesat2/processed_atl06/processed_ATL06_20200110122112_02260602_004_01_gt3r_spot1_A.h5')
# ('reading', 'data/icesat2/processed_atl06/processed_ATL06_20200114121252_02870602_004_01_gt3r_spot1_A.h5')
# ...

# %%
## merge all ascending/descending data
# ## Ascending
# !python utils/merge_files.py data/icesat2/processed_atl06/atl06_spot?_A.h5 -o data/icesat2/processed_atl06/atl06_A.h5
# ## Descending
# !python utils/merge_files.py data/icesat2/processed_atl06/atl06_spot?_D.h5 -o data/icesat2/processed_atl06/atl06_D.h5
# Out:
# Running sequential code ...
# Calculating lenght of output from all input files ...
# ('reading', 'data/icesat2/processed_atl06/atl06_spot1_A.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_spot2_A.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_spot3_A.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_spot4_A.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_spot5_A.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_spot6_A.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_spot1_A.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_spot2_A.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_spot3_A.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_spot4_A.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_spot5_A.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_spot6_A.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_spot1_A.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_spot2_A.h5')
# ...

# %%
## merge all data into one
## atl03
# !python utils/merge_files.py data/icesat2/processed_atl03/data_202012/*ATL03*_spot*.h5 -o data/icesat2/processed_atl03/data_202012/atl03_202012.h5
## atl06
# !python utils/merge_files.py data/icesat2/processed_atl06/atl06_2020*.h5 -o data/icesat2/processed_atl06/atl06_2020.h5
# Out:
# Running sequential code ...
# Calculating lenght of output from all input files ...
# ('reading', 'data/icesat2/processed_atl06/atl06_202001.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_202002.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_202003.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_202004.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_202005.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_202006.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_202007.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_202008.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_202009.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_202010.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_202011.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_202012.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_202001.h5')
# ('reading', 'data/icesat2/processed_atl06/atl06_202002.h5')
# ...

# %% [markdown]
# ### data subseting

# %%
# !python utils/subset_file.py data/icesat2/processed_atl03/atl03_2020??.h5 -m data/rgi/rgi60_1305_StudyArea/mask_based_dem.tif
# Out:
# Input arguments:
# ('ifile', ['data/icesat2/processed_atl03/atl03_202001.h5', 'data/icesat2/processed_atl03/atl03_202002.h5', 'data/icesat2/processed_atl03/atl03_202003.h5', 'data/icesat2/processed_atl03/atl03_202004.h5', 'data/icesat2/processed_atl03/atl03_202005.h5', 'data/icesat2/processed_atl03/atl03_202006.h5', 'data/icesat2/processed_atl03/atl03_202007.h5', 'data/icesat2/processed_atl03/atl03_202008.h5', 'data/icesat2/processed_atl03/atl03_202009.h5', 'data/icesat2/processed_atl03/atl03_202010.h5', 'data/icesat2/processed_atl03/atl03_202011.h5', 'data/icesat2/processed_atl03/atl03_202012.h5'])
# ('region', [None, None, None, None])
# ('time_range', [None, None])
# ('mask_file', ['data/rgi/rgi60_1305_StudyArea/mask_based_dem.tif'])
# ('coord_name', ['lon', 'lat'])
# ('time_name', ['t_year'])
# ('input -> ', 'data/icesat2/processed_atl03/atl03_202001.h5')
# ('output ->', 'data/icesat2/processed_atl03/atl03_202001_subs.h5')
# ...
